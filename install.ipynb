# %% [markdown]
# <a href="https://colab.research.google.com/github/emjayoh/sd-webui-colab-gdrive/blob/main/install.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
from google.colab import drive
drive.mount('/content/drive')

# %env PYTHONDONTWRITEBYTECODE=1

# !apt-get -y install -qq aria2

drive_loc = "/content/drive/MyDrive/stable-diffusion-webui-colab/stable-diffusion-webui"

# !git clone -b v2.0 https://github.com/camenduru/stable-diffusion-webui {drive_loc}
# !git clone https://huggingface.co/embed/negative {drive_loc}/embeddings/negative
# !git clone https://huggingface.co/embed/lora {drive_loc}/models/Lora/positive
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/embed/upscale/resolve/main/4x-UltraSharp.pth -d {drive_loc}/models/ESRGAN -o 4x-UltraSharp.pth
# !wget https://raw.githubusercontent.com/camenduru/stable-diffusion-webui-scripts/main/run_n_times.py -O {drive_loc}/scripts/run_n_times.py
# !git clone https://github.com/deforum-art/deforum-for-automatic1111-webui {drive_loc}/extensions/deforum-for-automatic1111-webui
# !git clone https://github.com/AlUlkesh/stable-diffusion-webui-images-browser {drive_loc}/extensions/stable-diffusion-webui-images-browser
# !git clone https://github.com/camenduru/stable-diffusion-webui-huggingface {drive_loc}/extensions/stable-diffusion-webui-huggingface
# !git clone -b v2.0 https://github.com/camenduru/sd-civitai-browser {drive_loc}/extensions/sd-civitai-browser
# !git clone https://github.com/kohya-ss/sd-webui-additional-networks {drive_loc}/extensions/sd-webui-additional-networks
# !git clone https://github.com/Mikubill/sd-webui-controlnet {drive_loc}/extensions/sd-webui-controlnet
# !git clone https://github.com/camenduru/openpose-editor {drive_loc}/extensions/openpose-editor
# !git clone https://github.com/jexom/sd-webui-depth-lib {drive_loc}/extensions/sd-webui-depth-lib
# !git clone https://github.com/hnmr293/posex {drive_loc}/extensions/posex
# !git clone https://github.com/camenduru/sd-webui-tunnels {drive_loc}/extensions/sd-webui-tunnels
# !git clone https://github.com/etherealxx/batchlinks-webui {drive_loc}/extensions/batchlinks-webui
# !git clone https://github.com/camenduru/stable-diffusion-webui-catppuccin {drive_loc}/extensions/stable-diffusion-webui-catppuccin
# !git clone https://github.com/KohakuBlueleaf/a1111-sd-webui-locon {drive_loc}/extensions/a1111-sd-webui-locon
# %cd {drive_loc}

# !git reset --hard
# !git pull
# !git -C {drive_loc}/extensions/deforum-for-automatic1111-webui reset --hard
# !git -C {drive_loc}/extensions/deforum-for-automatic1111-webui pull
# !git -C {drive_loc}/extensions/stable-diffusion-webui-images-browser reset --hard
# !git -C {drive_loc}/extensions/stable-diffusion-webui-images-browser pull
# !git -C {drive_loc}/extensions/stable-diffusion-webui-huggingface reset --hard
# !git -C {drive_loc}/extensions/stable-diffusion-webui-huggingface pull
# !git -C {drive_loc}/extensions/sd-civitai-browser reset --hard
# !git -C {drive_loc}/extensions/sd-civitai-browser pull
# !git -C {drive_loc}/extensions/sd-webui-additional-networks reset --hard
# !git -C {drive_loc}/extensions/sd-webui-additional-networks pull
# !git -C {drive_loc}/extensions/sd-webui-controlnet reset --hard
# !git -C {drive_loc}/extensions/sd-webui-controlnet pull
# !git -C {drive_loc}/extensions/openpose-editor reset --hard
# !git -C {drive_loc}/extensions/openpose-editor pull
# !git -C {drive_loc}/extensions/sd-webui-depth-lib reset --hard
# !git -C {drive_loc}/extensions/sd-webui-depth-lib pull
# !git -C {drive_loc}/extensions/posex reset --hard
# !git -C {drive_loc}/extensions/posex pull
# !git -C {drive_loc}/extensions/sd-webui-tunnels reset --hard
# !git -C {drive_loc}/extensions/sd-webui-tunnels pull
# !git -C {drive_loc}/extensions/batchlinks-webui reset --hard
# !git -C {drive_loc}/extensions/batchlinks-webui pull

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/hand_pose_model.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/openpose -o hand_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/body_pose_model.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/openpose -o body_pose_model.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/dpt_hybrid-midas-501f0c75.pt -d {drive_loc}/extensions/sd-webui-controlnet/annotator/midas -o dpt_hybrid-midas-501f0c75.pt
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_large_512_fp32.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_large_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/mlsd_tiny_512_fp32.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/mlsd -o mlsd_tiny_512_fp32.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/network-bsds500.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/hed -o network-bsds500.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/upernet_global_small.pth -d {drive_loc}/extensions/sd-webui-controlnet/annotator/uniformer -o upernet_global_small.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_canny-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_canny-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_depth-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_depth-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_hed-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_hed-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_mlsd-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_mlsd-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_normal-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_normal-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_openpose-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_openpose-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_scribble-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_scribble-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/control_seg-fp16.safetensors -d {drive_loc}/extensions/sd-webui-controlnet/models -o control_seg-fp16.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_style_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_style_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_sketch_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_sketch_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_keypose_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_keypose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_color_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_color_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_seg_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_seg_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_openpose_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_openpose_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_depth_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_depth_sd14v1.pth
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/ControlNet/resolve/main/t2iadapter_canny_sd14v1.pth -d {drive_loc}/extensions/sd-webui-controlnet/models -o t2iadapter_canny_sd14v1.pth

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd15/resolve/main/v1-5-pruned-emaonly.ckpt -d {drive_loc}/models/Stable-diffusion -o v1-5-pruned-emaonly.ckpt

# !sed -i -e 's/    start()/    #start()/g' {drive_loc}/launch.py
# !sed -i -e 's/checkout {commithash}/checkout --force {commithash}/g' {drive_loc}/launch.py

# %cd {drive_loc}
# !python launch.py --skip-torch-cuda-test

print("Installed")
